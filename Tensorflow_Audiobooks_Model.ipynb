# %% [markdown]
# # Audiobooks business case

# %% [markdown]
# ## Problem
#
# You are given data from an Audiobook app. Logically, it relates only to the audio versions of books. Each customer in the database has made a purchase at least once, that's why he/she is in the database. We want to create a machine learning algorithm based on our available data that can predict if a customer will buy again from the Audiobook company.
#
# The main idea is that if a customer has a low probability of coming back, there is no reason to spend any money on advertizing to him/her. If we can focus our efforts ONLY on customers that are likely to convert again, we can make great savings. Moreover, this model can identify the most important metrics for a customer to come back again. Identifying new customers creates value and growth opportunities.
#
# You have a .csv summarizing the data. There are several variables: Customer ID, Book length in mins_avg (average of all purchases), Book length in minutes_sum (sum of all purchases), Price Paid_avg (average of all purchases), Price paid_sum (sum of all purchases), Review (a Boolean variable), Review (out of 10), Total minutes listened, Completion (from 0 to 1), Support requests (number), and Last visited minus purchase date (in days).
#
# So these are the inputs (excluding customer ID, as it is completely arbitrary. It's more like a name, than a number).
#
# The targets are a Boolean variable (so 0, or 1). We are taking a period of 2 years in our inputs, and the next 6 months as targets. So, in fact, we are predicting if: based on the last 2 years of activity and engagement, a customer will convert in the next 6 months. 6 months sounds like a reasonable time. If they don't convert after 6 months, chances are they've gone to a competitor or didn't like the Audiobook way of digesting information.
#
# The task is simple: create a machine learning algorithm, which is able to predict if a customer will buy again.
#
# This is a classification problem with two classes: won't buy and will buy, represented by 0s and 1s.
#
# Good luck!

# %%
import numpy as np
import tensorflow as tf

# %% [markdown]
# #### import data

# %%
# Train
npz = np.load('Audiobooks_data_train.npz')
train_inputs, train_targets = npz['inputs'].astype(float), npz['targets'].astype(int)

# Validation
npz = np.load('Audiobooks_data_validation.npz')
validation_inputs, validation_targets = npz['inputs'].astype(float), npz['targets'].astype(int)

# Test
npz = np.load('Audiobooks_data_test.npz')
test_inputs, test_targets = npz['inputs'].astype(float), npz['targets'].astype(int)

# %% [markdown]
# #### Model

# %%
def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    
    else:
        return lr * tf.math.exp(-0.1)

# %%
input_size = 10
output_size = 2
hidden_layer_size = 50

model = tf.keras.Sequential([
    tf.keras.layers.Dense(hidden_layer_size, activation="relu"),
    tf.keras.layers.Dense(hidden_layer_size, activation="relu"),
    tf.keras.layers.Dense(output_size, activation="softmax")
])

optimizer = tf.optimizers.Adam(learning_rate=0.001)

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

BATCH_SIZE = 1000
EPOCHS = 100
early_stopping = tf.keras.callbacks.EarlyStopping(patience=2, monitor='val_loss')
learning_rate_schedule = tf.keras.callbacks.LearningRateScheduler(scheduler)

model.fit(train_inputs, 
          train_targets, 
          batch_size=BATCH_SIZE, 
          epochs=EPOCHS, 
          validation_data=(validation_inputs, validation_targets),
          callbacks=[early_stopping],
          verbose=2
         )
# Out:
# Epoch 1/100
# 2022-06-08 09:51:57.050352: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 4/4 - 1s - loss: 0.7187 - accuracy: 0.4820 - val_loss: 0.6874 - val_accuracy: 0.5011 - 516ms/epoch - 129ms/step
# Epoch 2/100
# 4/4 - 0s - loss: 0.6702 - accuracy: 0.5133 - val_loss: 0.6422 - val_accuracy: 0.5570 - 26ms/epoch - 6ms/step
# Epoch 3/100
# 4/4 - 0s - loss: 0.6311 - accuracy: 0.5624 - val_loss: 0.6055 - val_accuracy: 0.6040 - 25ms/epoch - 6ms/step
# Epoch 4/100
# 4/4 - 0s - loss: 0.5987 - accuracy: 0.6340 - val_loss: 0.5756 - val_accuracy: 0.6980 - 24ms/epoch - 6ms/step
# Epoch 5/100
# 4/4 - 0s - loss: 0.5722 - accuracy: 0.7077 - val_loss: 0.5507 - val_accuracy: 0.7315 - 26ms/epoch - 7ms/step
# Epoch 6/100
# 4/4 - 0s - loss: 0.5493 - accuracy: 0.7572 - val_loss: 0.5292 - val_accuracy: 0.7562 - 27ms/epoch - 7ms/step
# Epoch 7/100
# 4/4 - 0s - loss: 0.5295 - accuracy: 0.7639 - val_loss: 0.5104 - val_accuracy: 0.7808 - 26ms/epoch - 6ms/step
# Epoch 8/100
# 4/4 - 0s - loss: 0.5114 - accuracy: 0.7720 - val_loss: 0.4942 - val_accuracy: 0.7808 - 28ms/epoch - 7ms/step
# Epoch 9/100
# 4/4 - 0s - loss: 0.4956 - accuracy: 0.7706 - val_loss: 0.4797 - val_accuracy: 0.7785 - 26ms/epoch - 7ms/step
# Epoch 10/100
# 4/4 - 0s - loss: 0.4817 - accuracy: 0.7687 - val_loss: 0.4670 - val_accuracy: 0.7718 - 25ms/epoch - 6ms/step
# Epoch 11/100
# 4/4 - 0s - loss: 0.4693 - accuracy: 0.7723 - val_loss: 0.4557 - val_accuracy: 0.7785 - 29ms/epoch - 7ms/step
# Epoch 12/100
# 4/4 - 0s - loss: 0.4582 - accuracy: 0.7737 - val_loss: 0.4452 - val_accuracy: 0.7740 - 30ms/epoch - 7ms/step
# Epoch 13/100
# 4/4 - 0s - loss: 0.4486 - accuracy: 0.7762 - val_loss: 0.4358 - val_accuracy: 0.7763 - 30ms/epoch - 7ms/step
# Epoch 14/100
# 4/4 - 0s - loss: 0.4398 - accuracy: 0.7787 - val_loss: 0.4276 - val_accuracy: 0.7808 - 30ms/epoch - 7ms/step
# Epoch 15/100
# 4/4 - 0s - loss: 0.4322 - accuracy: 0.7793 - val_loss: 0.4201 - val_accuracy: 0.7919 - 29ms/epoch - 7ms/step
# Epoch 16/100
# 4/4 - 0s - loss: 0.4253 - accuracy: 0.7835 - val_loss: 0.4133 - val_accuracy: 0.8009 - 33ms/epoch - 8ms/step
# Epoch 17/100
# 4/4 - 0s - loss: 0.4193 - accuracy: 0.7849 - val_loss: 0.4071 - val_accuracy: 0.8009 - 28ms/epoch - 7ms/step
# Epoch 18/100
# 4/4 - 0s - loss: 0.4138 - accuracy: 0.7879 - val_loss: 0.4012 - val_accuracy: 0.8054 - 28ms/epoch - 7ms/step
# Epoch 19/100
# 4/4 - 0s - loss: 0.4090 - accuracy: 0.7890 - val_loss: 0.3957 - val_accuracy: 0.8054 - 29ms/epoch - 7ms/step
# Epoch 20/100
# 4/4 - 0s - loss: 0.4043 - accuracy: 0.7899 - val_loss: 0.3908 - val_accuracy: 0.8188 - 30ms/epoch - 7ms/step
# Epoch 21/100
# 4/4 - 0s - loss: 0.4002 - accuracy: 0.7924 - val_loss: 0.3865 - val_accuracy: 0.8210 - 28ms/epoch - 7ms/step
# Epoch 22/100
# 4/4 - 0s - loss: 0.3965 - accuracy: 0.7949 - val_loss: 0.3820 - val_accuracy: 0.8255 - 29ms/epoch - 7ms/step
# Epoch 23/100
# 4/4 - 0s - loss: 0.3931 - accuracy: 0.7983 - val_loss: 0.3780 - val_accuracy: 0.8233 - 30ms/epoch - 8ms/step
# Epoch 24/100
# 4/4 - 0s - loss: 0.3900 - accuracy: 0.7994 - val_loss: 0.3737 - val_accuracy: 0.8322 - 28ms/epoch - 7ms/step
# Epoch 25/100
# 4/4 - 0s - loss: 0.3871 - accuracy: 0.8033 - val_loss: 0.3698 - val_accuracy: 0.8322 - 29ms/epoch - 7ms/step
# Epoch 26/100
# 4/4 - 0s - loss: 0.3844 - accuracy: 0.8036 - val_loss: 0.3670 - val_accuracy: 0.8322 - 30ms/epoch - 7ms/step
# Epoch 27/100
# 4/4 - 0s - loss: 0.3822 - accuracy: 0.8036 - val_loss: 0.3641 - val_accuracy: 0.8233 - 29ms/epoch - 7ms/step
# Epoch 28/100
# 4/4 - 0s - loss: 0.3797 - accuracy: 0.8064 - val_loss: 0.3613 - val_accuracy: 0.8345 - 30ms/epoch - 7ms/step
# Epoch 29/100
# 4/4 - 0s - loss: 0.3778 - accuracy: 0.8080 - val_loss: 0.3582 - val_accuracy: 0.8255 - 30ms/epoch - 7ms/step
# Epoch 30/100
# 4/4 - 0s - loss: 0.3755 - accuracy: 0.8072 - val_loss: 0.3557 - val_accuracy: 0.8277 - 29ms/epoch - 7ms/step
# Epoch 31/100
# 4/4 - 0s - loss: 0.3738 - accuracy: 0.8080 - val_loss: 0.3536 - val_accuracy: 0.8277 - 29ms/epoch - 7ms/step
# Epoch 32/100
# 4/4 - 0s - loss: 0.3722 - accuracy: 0.8086 - val_loss: 0.3513 - val_accuracy: 0.8345 - 29ms/epoch - 7ms/step
# Epoch 33/100
# 4/4 - 0s - loss: 0.3705 - accuracy: 0.8089 - val_loss: 0.3493 - val_accuracy: 0.8345 - 29ms/epoch - 7ms/step
# Epoch 34/100
# 4/4 - 0s - loss: 0.3691 - accuracy: 0.8103 - val_loss: 0.3471 - val_accuracy: 0.8367 - 29ms/epoch - 7ms/step
# Epoch 35/100
# 4/4 - 0s - loss: 0.3681 - accuracy: 0.8097 - val_loss: 0.3454 - val_accuracy: 0.8345 - 29ms/epoch - 7ms/step
# Epoch 36/100
# 4/4 - 0s - loss: 0.3664 - accuracy: 0.8103 - val_loss: 0.3443 - val_accuracy: 0.8277 - 29ms/epoch - 7ms/step
# Epoch 37/100
# 4/4 - 0s - loss: 0.3650 - accuracy: 0.8139 - val_loss: 0.3417 - val_accuracy: 0.8277 - 28ms/epoch - 7ms/step
# Epoch 38/100
# 4/4 - 0s - loss: 0.3635 - accuracy: 0.8131 - val_loss: 0.3398 - val_accuracy: 0.8389 - 27ms/epoch - 7ms/step
# Epoch 39/100
# 4/4 - 0s - loss: 0.3623 - accuracy: 0.8145 - val_loss: 0.3386 - val_accuracy: 0.8322 - 28ms/epoch - 7ms/step
# Epoch 40/100
# 4/4 - 0s - loss: 0.3611 - accuracy: 0.8159 - val_loss: 0.3378 - val_accuracy: 0.8277 - 29ms/epoch - 7ms/step
# Epoch 41/100
# 4/4 - 0s - loss: 0.3601 - accuracy: 0.8153 - val_loss: 0.3363 - val_accuracy: 0.8233 - 30ms/epoch - 7ms/step
# Epoch 42/100
# 4/4 - 0s - loss: 0.3592 - accuracy: 0.8170 - val_loss: 0.3340 - val_accuracy: 0.8389 - 28ms/epoch - 7ms/step
# Epoch 43/100
# 4/4 - 0s - loss: 0.3584 - accuracy: 0.8156 - val_loss: 0.3334 - val_accuracy: 0.8322 - 29ms/epoch - 7ms/step
# Epoch 44/100
# 4/4 - 0s - loss: 0.3574 - accuracy: 0.8181 - val_loss: 0.3328 - val_accuracy: 0.8367 - 29ms/epoch - 7ms/step
# Epoch 45/100
# 4/4 - 0s - loss: 0.3563 - accuracy: 0.8203 - val_loss: 0.3320 - val_accuracy: 0.8389 - 28ms/epoch - 7ms/step
# Epoch 46/100
# 4/4 - 0s - loss: 0.3557 - accuracy: 0.8187 - val_loss: 0.3311 - val_accuracy: 0.8277 - 31ms/epoch - 8ms/step
# Epoch 47/100
# 4/4 - 0s - loss: 0.3548 - accuracy: 0.8195 - val_loss: 0.3298 - val_accuracy: 0.8322 - 27ms/epoch - 7ms/step
# Epoch 48/100
# 4/4 - 0s - loss: 0.3542 - accuracy: 0.8206 - val_loss: 0.3291 - val_accuracy: 0.8412 - 29ms/epoch - 7ms/step
# Epoch 49/100
# 4/4 - 0s - loss: 0.3537 - accuracy: 0.8192 - val_loss: 0.3285 - val_accuracy: 0.8345 - 29ms/epoch - 7ms/step
# Epoch 50/100
# 4/4 - 0s - loss: 0.3527 - accuracy: 0.8198 - val_loss: 0.3291 - val_accuracy: 0.8300 - 29ms/epoch - 7ms/step
# Epoch 51/100
# 4/4 - 0s - loss: 0.3524 - accuracy: 0.8189 - val_loss: 0.3277 - val_accuracy: 0.8345 - 28ms/epoch - 7ms/step
# Epoch 52/100
# 4/4 - 0s - loss: 0.3516 - accuracy: 0.8223 - val_loss: 0.3258 - val_accuracy: 0.8389 - 24ms/epoch - 6ms/step
# Epoch 53/100
# 4/4 - 0s - loss: 0.3507 - accuracy: 0.8217 - val_loss: 0.3255 - val_accuracy: 0.8389 - 26ms/epoch - 6ms/step
# Epoch 54/100
# 4/4 - 0s - loss: 0.3500 - accuracy: 0.8209 - val_loss: 0.3255 - val_accuracy: 0.8300 - 24ms/epoch - 6ms/step
# Epoch 55/100
# 4/4 - 0s - loss: 0.3496 - accuracy: 0.8215 - val_loss: 0.3248 - val_accuracy: 0.8367 - 25ms/epoch - 6ms/step
# Epoch 56/100
# 4/4 - 0s - loss: 0.3493 - accuracy: 0.8234 - val_loss: 0.3244 - val_accuracy: 0.8456 - 26ms/epoch - 6ms/step
# Epoch 57/100
# 4/4 - 0s - loss: 0.3488 - accuracy: 0.8217 - val_loss: 0.3229 - val_accuracy: 0.8434 - 24ms/epoch - 6ms/step
# Epoch 58/100
# 4/4 - 0s - loss: 0.3487 - accuracy: 0.8209 - val_loss: 0.3227 - val_accuracy: 0.8389 - 25ms/epoch - 6ms/step
# Epoch 59/100
# 4/4 - 0s - loss: 0.3479 - accuracy: 0.8237 - val_loss: 0.3229 - val_accuracy: 0.8412 - 24ms/epoch - 6ms/step
# Epoch 60/100
# 4/4 - 0s - loss: 0.3471 - accuracy: 0.8234 - val_loss: 0.3216 - val_accuracy: 0.8367 - 25ms/epoch - 6ms/step
# Epoch 61/100
# 4/4 - 0s - loss: 0.3466 - accuracy: 0.8220 - val_loss: 0.3207 - val_accuracy: 0.8456 - 24ms/epoch - 6ms/step
# Epoch 62/100
# 4/4 - 0s - loss: 0.3457 - accuracy: 0.8237 - val_loss: 0.3208 - val_accuracy: 0.8389 - 24ms/epoch - 6ms/step
# Epoch 63/100
# 4/4 - 0s - loss: 0.3454 - accuracy: 0.8240 - val_loss: 0.3205 - val_accuracy: 0.8389 - 25ms/epoch - 6ms/step
# Epoch 64/100
# 4/4 - 0s - loss: 0.3451 - accuracy: 0.8234 - val_loss: 0.3191 - val_accuracy: 0.8389 - 24ms/epoch - 6ms/step
# Epoch 65/100
# 4/4 - 0s - loss: 0.3448 - accuracy: 0.8234 - val_loss: 0.3192 - val_accuracy: 0.8367 - 25ms/epoch - 6ms/step
# Epoch 66/100
# 4/4 - 0s - loss: 0.3443 - accuracy: 0.8243 - val_loss: 0.3186 - val_accuracy: 0.8456 - 24ms/epoch - 6ms/step
# Epoch 67/100
# 4/4 - 0s - loss: 0.3438 - accuracy: 0.8248 - val_loss: 0.3184 - val_accuracy: 0.8389 - 25ms/epoch - 6ms/step
# Epoch 68/100
# 4/4 - 0s - loss: 0.3437 - accuracy: 0.8243 - val_loss: 0.3177 - val_accuracy: 0.8479 - 24ms/epoch - 6ms/step
# Epoch 69/100
# 4/4 - 0s - loss: 0.3434 - accuracy: 0.8217 - val_loss: 0.3175 - val_accuracy: 0.8367 - 24ms/epoch - 6ms/step
# Epoch 70/100
# 4/4 - 0s - loss: 0.3433 - accuracy: 0.8231 - val_loss: 0.3173 - val_accuracy: 0.8456 - 25ms/epoch - 6ms/step
# Epoch 71/100
# 4/4 - 0s - loss: 0.3422 - accuracy: 0.8243 - val_loss: 0.3163 - val_accuracy: 0.8412 - 23ms/epoch - 6ms/step
# Epoch 72/100
# 4/4 - 0s - loss: 0.3422 - accuracy: 0.8240 - val_loss: 0.3159 - val_accuracy: 0.8456 - 24ms/epoch - 6ms/step
# Epoch 73/100
# 4/4 - 0s - loss: 0.3418 - accuracy: 0.8243 - val_loss: 0.3167 - val_accuracy: 0.8434 - 37ms/epoch - 9ms/step
# Epoch 74/100
# 4/4 - 0s - loss: 0.3417 - accuracy: 0.8256 - val_loss: 0.3158 - val_accuracy: 0.8367 - 24ms/epoch - 6ms/step
# Epoch 75/100
# 4/4 - 0s - loss: 0.3414 - accuracy: 0.8234 - val_loss: 0.3158 - val_accuracy: 0.8479 - 23ms/epoch - 6ms/step
# Epoch 76/100
# 4/4 - 0s - loss: 0.3408 - accuracy: 0.8243 - val_loss: 0.3155 - val_accuracy: 0.8389 - 23ms/epoch - 6ms/step
# Epoch 77/100
# 4/4 - 0s - loss: 0.3411 - accuracy: 0.8220 - val_loss: 0.3152 - val_accuracy: 0.8389 - 23ms/epoch - 6ms/step
# Epoch 78/100
# 4/4 - 0s - loss: 0.3408 - accuracy: 0.8243 - val_loss: 0.3156 - val_accuracy: 0.8501 - 22ms/epoch - 6ms/step
# Epoch 79/100
# 4/4 - 0s - loss: 0.3399 - accuracy: 0.8256 - val_loss: 0.3149 - val_accuracy: 0.8345 - 26ms/epoch - 7ms/step
# Epoch 80/100
# 4/4 - 0s - loss: 0.3411 - accuracy: 0.8198 - val_loss: 0.3140 - val_accuracy: 0.8412 - 30ms/epoch - 7ms/step
# Epoch 81/100
# 4/4 - 0s - loss: 0.3418 - accuracy: 0.8209 - val_loss: 0.3162 - val_accuracy: 0.8456 - 25ms/epoch - 6ms/step
# Epoch 82/100
# 4/4 - 0s - loss: 0.3400 - accuracy: 0.8256 - val_loss: 0.3149 - val_accuracy: 0.8300 - 24ms/epoch - 6ms/step
